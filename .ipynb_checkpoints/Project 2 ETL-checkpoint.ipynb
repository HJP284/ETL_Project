# %%
# Getting a list of Nightclubs in San Francisco
# We want to demostrate the use of APIs

# Dependencies
import requests
import json
import os
import gmaps
from pandas.io.json import json_normalize
import numpy as np
import pandas as pd
import requests
import time

# Google  API key
from config import gkey

gmaps.configure(api_key=gkey)

# %%
# Getting a list of Nightclubs in San Francisco
# We want to demostrate the use of APIs

# %%
target_coordinates = "37.7749,-122.4194"
target_search = "Nightclub"
target_radius = 50000
target_type = "nightclub"

# Setting up parameters
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
sf_clubs = response.json()

# Print the json (pretty printed)
print(json.dumps(sf_clubs, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCKwEAAMrolWFSRpJNth99WcuHJDFmCT8eQpXUvW0HIlytT199p29pCv8nlowVfXuOQrqdpnnmV3HflxVkG96Z5HJVsmelA6gN_nKL3E1RYl9EuIJzDrHHu4BHHzKf2Qza_TwGECVSksiA5IBoPrX7nLYHf2PG_952MbSKKcR98CVqf_wZ4DKQNMj0MQHJfO_SNgo9_xPJReocax_IqwRx_-VfL6kfj0numzsoLnpBEfdkEC-hO2ddmwkOT13aWLcTlF-eyxNokxoTAL3pV5ypn3jw7_7HljuFcjX5_LYPJnKkyaa5i2R1GZ8t64SsDqx_QoNndsY4rxoB4lZov-VyJAlRYj02e0yIaFRx1NJAS9AqvGJzBnEb15Zy6BffFh6PKFnLtwRSXSUYBAStkFdq7FsKvCcSEO2tm0n7x-a414TSSiKshNIaFFNeBlxQIit5rD1g5J-5av8wRXg5",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.3768037,
#                     "lng": -122.0298038
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.37818862989272,
#                         "lng": -122.0286148701073
#                     },
#                     "southwest": {
#                         "lat": 37.37548897010728,
#                         "lng": -122.0313145298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "1501bbd4f27bc5192be2721519813f6b11660d69",
#             "name": "Pure Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116548265877372563340/photos\">Steven Leung</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyD8o5GxSvkdHVpKlyn-O-g2i6lAusy4Mh9RCJfHPNYVhdyYPiMZbf0i5zA4RgnbrrL0pm-r3FVvY1FTHr2PZIv6cOGYK0obTRJqxPJ2alSS7f2yiPOpHWiMyG9rfW8HaEhCcbgN_eqZ8D_Y-RXt_nQWbGhQ6hPgCwQBFoIwGtbWHFklHT4-CGQ",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ5RwEVly2j4ARAAp9ATndYxc",
#             "plus_code": {
#                 "compound_code": "9XGC+P3 Sunnyvale, California",
#                 "global_code": "849V9XGC+P3"
#             },
#             "price_level": 2,
#             "rating": 3.5,
#             "reference": "ChIJ5RwEVly2j4ARAAp9ATndYxc",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 152,
#             "vicinity": "146 S Murphy Ave, Sunnyvale"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.797948,
#                     "lng": -122.4047847
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.79938112989272,
#                         "lng": -122.4034520201073
#                     },
#                     "southwest": {
#                         "lat": 37.79668147010728,
#                         "lng": -122.4061516798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "f7b4baafbb37bf537134c1743bc77e4750702325",
#             "name": "HUE",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100319726892602982658/photos\">Gleizy Fonseca</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJ_kED74HtdtildcfQ68Ou1h7TZA4-sFfo9NB8cANFI0i1Vho6vH2dkKakNx2FloqsVrbT27rAe11RcGE0Oahaqi3HwJmL2XqypnjnEfLxJvNqZzLLe2MAP4h58rvzzaVEhBqsXt_PNNRUT1_XhLeXfUWGhS13d4B6qiFqeFi1x-v_lBwmvwAKg",
#                     "width": 1944
#                 }
#             ],
#             "place_id": "ChIJFXzz-PSAhYARdawj6Vezo9g",
#             "plus_code": {
#                 "compound_code": "QHXW+53 Financial District, San Francisco, CA",
#                 "global_code": "849VQHXW+53"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJFXzz-PSAhYARdawj6Vezo9g",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "447 Broadway, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7838841,
#                     "lng": -122.4325529
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78524017989272,
#                         "lng": -122.4313492201073
#                     },
#                     "southwest": {
#                         "lat": 37.78254052010728,
#                         "lng": -122.4340488798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "35ff479da7dfc5ce3ff136b26a82f693a4a9569a",
#             "name": "Origin",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109441328719820863810/photos\">Marie Luise Cajayon</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAsLlFyJGi8Dhgd44zmuTYtAZX98MV4Xey_JXkCoUMtLnTALtWOAnVoNPBzq_BN6AchdIAhYlRPloCJm-ZoCDBem16sqkgYzbdqL97KMWvCH5ySPoIYw_rCaZBnnA09ILeEhBGLur45rCRpS5cAHI8SWXfGhTOi0xnLxZhq9H6cOdh4ZqYOef1UQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJMx0ap7mAhYARaJPoM6Pc6eg",
#             "plus_code": {
#                 "compound_code": "QHM8+HX Western Addition, San Francisco, CA",
#                 "global_code": "849VQHM8+HX"
#             },
#             "price_level": 2,
#             "rating": 3.3,
#             "reference": "ChIJMx0ap7mAhYARaJPoM6Pc6eg",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 48,
#             "vicinity": "1538 Fillmore St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.775291,
#                     "lng": -122.4099614
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77659607989272,
#                         "lng": -122.4085484701073
#                     },
#                     "southwest": {
#                         "lat": 37.77389642010728,
#                         "lng": -122.4112481298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "3e0a894f8704a08e0b968127c47a2c82750664a2",
#             "name": "F8",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111373865606276521052/photos\">Charley Ho</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbOMK3cTz2ik_Vtf_d80zlWbFsDnmQMQ-rq4IrlpAbmr_vgdTl5SxbBWnMhjsKslZeGTKEYMTt_Tke3aFSMiQPjXuSyIW7KscR5zNeSTLsStaoy1JWMAtOfIPhoNJCk4iEhAoTRkTtYWtP9H0R2S0Z09DGhR444E3ZVoxa40nU6bkJd5jKEId3g",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJm5TigIKAhYARZ_AATy2Ieu4",
#             "plus_code": {
#                 "compound_code": "QHGR+42 SoMa, San Francisco, CA",
#                 "global_code": "849VQHGR+42"
#             },
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "ChIJm5TigIKAhYARZ_AATy2Ieu4",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 147,
#             "vicinity": "1192 Folsom St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7790996,
#                     "lng": -122.3979003
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78050357989272,
#                         "lng": -122.3964783201073
#                     },
#                     "southwest": {
#                         "lat": 37.77780392010728,
#                         "lng": -122.3991779798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "18e74c4aa201e64722d8414f3166d180244d8aa9",
#             "name": "The Grand",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4903,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102119050734171212729/photos\">Liz Cantu Davenport</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA07ZizOhRpkZEq_N8FSCBh8s4q_-3I2HQqGMewKgw4gC9cj9BnZiJWCvs0mV-boJTtxHYHX-6aAz4vSUmmUhZKzTW68TUdCEJVFRuQ4pr8rsqHauOQ_5nsNWR1r5MppfmEhBbjvZmoZ6HUtSf6iGv8RgaGhTt0E_011OiQ2zgmBC2AFEmjmHdHw",
#                     "width": 7347
#                 }
#             ],
#             "place_id": "ChIJO6fCZH-AhYARbmHHgxnFxB8",
#             "plus_code": {
#                 "compound_code": "QJH2+JR SoMa, San Francisco, CA",
#                 "global_code": "849VQJH2+JR"
#             },
#             "price_level": 3,
#             "rating": 3.5,
#             "reference": "ChIJO6fCZH-AhYARbmHHgxnFxB8",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 112,
#             "vicinity": "520 4th St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7713746,
#                     "lng": -122.4143099
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77279862989273,
#                         "lng": -122.4130640701073
#                     },
#                     "southwest": {
#                         "lat": 37.77009897010728,
#                         "lng": -122.4157637298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "52f749412fccb5f7372d8a461cc80fc455e3f8cb",
#             "name": "The Holy Cow",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103348007688594899143/photos\">Preksha Shukla</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAG7c4Aa_0ToHzA-VStKpf0PW0oYo_oFL4JHAZkHk4FyuNmhdtPW6-B0uFoQJZbPYcnuWnm_Fp_Gfo26BioVBvz-BQW9ryRuUb0JuoZjLEWlCEokmy14h7kFSLJHead6FAEhBfv8uwlLtzJrMf1708rQyoGhT-BBfY2oqZVLktVijF29KQ8YDzrg",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJMTRftCd-j4ARWTvQZOTDNM0",
#             "plus_code": {
#                 "compound_code": "QHCP+G7 SoMa, San Francisco, CA",
#                 "global_code": "849VQHCP+G7"
#             },
#             "price_level": 2,
#             "rating": 3.1,
#             "reference": "ChIJMTRftCd-j4ARWTvQZOTDNM0",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 60,
#             "vicinity": "1535 Folsom St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.9728783,
#                     "lng": -122.5247984
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.97417192989272,
#                         "lng": -122.5234594201073
#                     },
#                     "southwest": {
#                         "lat": 37.97147227010728,
#                         "lng": -122.5261590798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "97c7e73f498887a2e8fa0459a49e913e33e5d51b",
#             "name": "George's Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111810312065171874458/photos\">Josue Gabriel Chicas</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAa1OwaPhW9O-d0MNEjsdNaLatyi3RvdkrehKQOcGXdxp1gJ4EMGk7iDTzVJkUwffeUqp8yBYc1e9NU6bcSxtM48fh6hyGSq2yCV_5Bct489ArMZr6Y9sjaHyCEtLoPgLrEhAhXaV-WjPkCVpwJCsqUg6QGhSgFj_S_6VBTQOdnc2VKSoR4oGfKQ",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJAWd8tPCZhYARQtzK8sBGjW0",
#             "plus_code": {
#                 "compound_code": "XFFG+53 San Rafael, California",
#                 "global_code": "849VXFFG+53"
#             },
#             "rating": 3.3,
#             "reference": "ChIJAWd8tPCZhYARQtzK8sBGjW0",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "842 4th St, San Rafael"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.771362,
#                     "lng": -122.413792
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77278862989272,
#                         "lng": -122.4123443701072
#                     },
#                     "southwest": {
#                         "lat": 37.77008897010727,
#                         "lng": -122.4150440298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "e1edec5cd007c1172a4af29b0ac8fa96298e7185",
#             "name": "Audio Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1440,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100366883861598066793/photos\">Frank Ebert</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAg074p6z42v912aA2PEmtodw4bP8ToIysZ8Af-I4KTCwpl_b4Lm38-yy_2g9CeCBmm-CcUSV1-wHGWfJfSZNI1qMPDUqBu_Y7TErx8v35-l6_ltZp0MjjYneQdSvBaq4rEhAFZkKV87goU9dLeQYtckNWGhRSAZhLoso9NDSUOCUWr0CIa17RXQ",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJ-45DMyZ-j4AR2Apt3H8M8W8",
#             "plus_code": {
#                 "compound_code": "QHCP+GF SoMa, San Francisco, CA",
#                 "global_code": "849VQHCP+GF"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJ-45DMyZ-j4AR2Apt3H8M8W8",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 166,
#             "vicinity": "316 11th St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7781268,
#                     "lng": -122.405787
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77955922989271,
#                         "lng": -122.4045067201073
#                     },
#                     "southwest": {
#                         "lat": 37.77685957010727,
#                         "lng": -122.4072063798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "e30254400171df555b96784f93c4168a4cdb511a",
#             "name": "1015 Folsom",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110735291300890193560/photos\">rWilliam Brown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnavcc3SUEFpHIxIgbdx1CB6lJ6nR-XpXzvZ-LdbRFB_jepdkAiWjXLkQo7k9puACgUTamAGn7E_fLhaIzsVphiv4V-r9SRo3pRfcY46afoIc7OsK-vLXFGrvgtnL5evZEhBRhaLMbsq_49pZujcds-rbGhTs2HAlqHuM8Moh4iK7NZOrCmt3IA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJRwXhl4GAhYARKMdYXvUW1m8",
#             "plus_code": {
#                 "compound_code": "QHHV+7M SoMa, San Francisco, CA",
#                 "global_code": "849VQHHV+7M"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJRwXhl4GAhYARKMdYXvUW1m8",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 251,
#             "vicinity": "1015 Folsom St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7885694,
#                     "lng": -122.3981969
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78988832989272,
#                         "lng": -122.3968000701073
#                     },
#                     "southwest": {
#                         "lat": 37.78718867010727,
#                         "lng": -122.3994997298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "d666f7f1fa3af01c56f0265c7cee49d67e3298e9",
#             "name": "Harlot",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101194371142924116371/photos\">Houdini</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcwbXdlHSSdbyHbCxRcJSODpMEWcgm4vUcjX2k6u-kmMjCmLEB2j8x9-uH3YqE_kRoFHN9TnykFckLzi4FrbeILlFCJoivmWyrt-zUT5w92jg3Q3QkY9pQ9zJ1hqZHOKYEhACrvA_SeR6IfXV5cRf7wRdGhS3mGM1LYgSFFGQpKpO4Ei_8KoVJw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ_wvnLmOAhYARfjey1qtQmg4",
#             "plus_code": {
#                 "compound_code": "QJQ2+CP SoMa, San Francisco, CA",
#                 "global_code": "849VQJQ2+CP"
#             },
#             "price_level": 3,
#             "rating": 3.7,
#             "reference": "ChIJ_wvnLmOAhYARfjey1qtQmg4",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 94,
#             "vicinity": "46 Minna St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.9868616,
#                     "lng": -122.5879555
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.98820787989273,
#                         "lng": -122.5865386701073
#                     },
#                     "southwest": {
#                         "lat": 37.98550822010728,
#                         "lng": -122.5892383298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "90469932a147bede21fc205590233bdf4955175e",
#             "name": "19 Broadway",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111166131312787211650/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAkk0F2--N5-rxEgq6KytlzuvX3_xGT-GD-PeQGBZHOvMYGZhxpPeDpFrpIgN372eGg6Nyn_1ZRlqyaiLCNz1paoY5Ivq_jO82He9Vc1Gf98H0LF8n_dp_M9izgN4BGxv9EhCWOGpoYUqFiv9CttZT1LtrGhSYoC0PwJFZ9djCijS717J9NdXYiw",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ44vR_FWWhYARNIvh6gYMTUY",
#             "plus_code": {
#                 "compound_code": "XCP6+PR Fairfax, California",
#                 "global_code": "849VXCP6+PR"
#             },
#             "price_level": 2,
#             "rating": 4.5,
#             "reference": "ChIJ44vR_FWWhYARNIvh6gYMTUY",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "19 Broadway, Fairfax"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.77548,
#                     "lng": -121.976335
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77667642989272,
#                         "lng": -121.9750554701073
#                     },
#                     "southwest": {
#                         "lat": 37.77397677010728,
#                         "lng": -121.9777551298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "d3be690b01527cbab112ba0a722f562913d7c2ea",
#             "name": "ShBoom Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 513,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115091909746257986308/photos\">ShBoom Nightclub</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAu9kUeG8DRVMDyGQqCp2jzRba0VTq9M6Vsm_zVjJ_4nL4atnu6cr2YKTwih5scOZ5PxOr-frYYhbk4sCKRzF3XSwFdKSCH2CEOxhuoziooKvdnrRB6SpQb2mrXEOymIXpEhDvrPhh5jjjJB046oAH63bsGhRcmMk27HAIlGJz9klaVvZe6LIs2Q",
#                     "width": 793
#                 }
#             ],
#             "place_id": "ChIJR-2WNsfyj4AR7uefmq-1xI0",
#             "plus_code": {
#                 "compound_code": "Q2GF+5F San Ramon, California",
#                 "global_code": "849WQ2GF+5F"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJR-2WNsfyj4AR7uefmq-1xI0",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 86,
#             "vicinity": "2410 San Ramon Valley Blvd #130, San Ramon"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.771972,
#                     "lng": -122.4144509
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77336507989272,
#                         "lng": -122.4130118701073
#                     },
#                     "southwest": {
#                         "lat": 37.77066542010727,
#                         "lng": -122.4157115298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "a6e86de55360cfbe76a9b651f0d2d2b3bf867280",
#             "name": "OASIS",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116420115838609488002/photos\">Oasis</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxgIywxGLS46Wn0ubsJQaYl1TsDEzhJgqN5dOaROI0FHbArgtI-CS0vZNPJ1hfhqx4vQP9QNv1Ktbp52tWcdWbWELkkN6kNlwZEy1OQU7gXSNbqyVQ9-asvTuq95eB8PWEhAJOktLtLdyB9ZRcnHLG5cPGhR2sds9pfiyWSzzY1r8WcXaLr8CTg",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJt3rauSd-j4ARlPtSevL_VQY",
#             "plus_code": {
#                 "compound_code": "QHCP+Q6 SoMa, San Francisco, CA",
#                 "global_code": "849VQHCP+Q6"
#             },
#             "rating": 4.3,
#             "reference": "ChIJt3rauSd-j4ARlPtSevL_VQY",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 74,
#             "vicinity": "298 11th St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.8085876,
#                     "lng": -122.269635
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.80995777989272,
#                         "lng": -122.2683785201072
#                     },
#                     "southwest": {
#                         "lat": 37.80725812010727,
#                         "lng": -122.2710781798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "5dc37f315cc16fb4912ebd5def8449fdbbe03935",
#             "name": "The Uptown Nightclub!",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 750,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111649149702197963031/photos\">Uptown Night Club</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcBG0ipRtN1My4X-fEQDs5MCBLHuUWqFrsUcj_1va3NjO9kxpJ6U2kQ1qYhOyLEaNl8Mmg7wFhUQ0_CmUv56K1uTCU6VPm0_-mrz8zmOaawNRRF3TcY6pglgFKv_WAXxwEhAdVIUeHmxPET47yqVq0vCFGhQCsaLZ_sOnQx5zPt8qxSLIYrulMg",
#                     "width": 1800
#                 }
#             ],
#             "place_id": "ChIJW1nriq2Aj4ARfDmscjzBQyk",
#             "plus_code": {
#                 "compound_code": "RP5J+C4 Oakland, California",
#                 "global_code": "849VRP5J+C4"
#             },
#             "rating": 4.2,
#             "reference": "ChIJW1nriq2Aj4ARfDmscjzBQyk",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "1928 Telegraph Ave, Oakland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7961123,
#                     "lng": -122.421932
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.79739042989273,
#                         "lng": -122.4205290201073
#                     },
#                     "southwest": {
#                         "lat": 37.79469077010728,
#                         "lng": -122.4232286798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "f3f5ba9170340f1be6667e4367ca00b6fcb72c44",
#             "name": "Rouge Night Club",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108615940274457531719/photos\">Rouge Night Club</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAC7QsUaJsysu13ycpZ_BxJe6SpBeh2q4WjYJtoZr6iCC2Q2R6aDhbuMv8lve8PkDmH39UIxLc4mrSDAQgx4MQn2AIq4AqZGiRLpQbnTiVEgjO2gZnFGFtN0MkSkzuztRQEhC5mBLLMnSwoutBJFxFrsmfGhQmyBHznJUYCjJ4qcgsnp4n8h8Qcg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJe3uYkOmAhYAR8gdCXjJNyeQ",
#             "plus_code": {
#                 "compound_code": "QHWH+C6 Russian Hill, San Francisco, CA",
#                 "global_code": "849VQHWH+C6"
#             },
#             "price_level": 2,
#             "rating": 3.4,
#             "reference": "ChIJe3uYkOmAhYAR8gdCXjJNyeQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "1500 Broadway, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7820604,
#                     "lng": -122.3976355
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78345047989273,
#                         "lng": -122.3964383701073
#                     },
#                     "southwest": {
#                         "lat": 37.78075082010728,
#                         "lng": -122.3991380298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "8467a5e7b16a2cb3c958b5d784b7a7a72657b540",
#             "name": "City Nights",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111881477538410001809/photos\">Matthew Zolezzi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyFlGNgbKKXAocV_s6gQNRyaDMi9e3fsxYvi_2z9FhpHDUgbRRHSWy4oe4FCbX70kvqgOr-q-KkMawGjNOO8CAWRtDkOaW4mQd-zx9tjrvqBji0yqPtLekRkR1ErOiUDBEhBVHyRuwkHjBdjcVfR21kjaGhSH-ydZhBKTTLOs9032ZBCP4zNNhA",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJeZ2e7n6AhYARVjvP9N8mEcs",
#             "plus_code": {
#                 "compound_code": "QJJ2+RW SoMa, San Francisco, CA",
#                 "global_code": "849VQJJ2+RW"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJeZ2e7n6AhYARVjvP9N8mEcs",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 110,
#             "vicinity": "715 Harrison St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.337288,
#                     "lng": -121.8887537
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.33855107989272,
#                         "lng": -121.8873378201072
#                     },
#                     "southwest": {
#                         "lat": 37.33585142010728,
#                         "lng": -121.8900374798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "133eb3a6943aa2deeef3be8a9a184ac0a84e2bf1",
#             "name": "ENSO Bar & Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3056,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100154901588069212708/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6m_5a1DsgAT-ehhPgbMoeAtFI2L2Zf9E4RARZdoIZifdqKgznUIT1kswtgyKJfVorer6ABIVlMorOb8NJnTv4BL0CdwAJwPUKgRHNS9JeByJp2G0fuADddZX9mkh4Dx4EhCtPkk3Y4xCmTOA-W6EeqUxGhS9NlNdkFEOU3HR9dX8Nd8Yy5yd6Q",
#                     "width": 4592
#                 }
#             ],
#             "place_id": "ChIJG5FGHr3Mj4ART-GSHQlVhHU",
#             "plus_code": {
#                 "compound_code": "84P6+WF San Jose, California",
#                 "global_code": "849W84P6+WF"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJG5FGHr3Mj4ART-GSHQlVhHU",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 172,
#             "vicinity": "97 E Santa Clara St, San Jose"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7887903,
#                     "lng": -122.4065981
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.79025292989272,
#                         "lng": -122.4052492201073
#                     },
#                     "southwest": {
#                         "lat": 37.78755327010727,
#                         "lng": -122.4079488798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "83528866af26da1035875c3ea3b6528490ddc95a",
#             "name": "Love + Propaganda",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 683,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102527170037305091749/photos\">Love and Propaganda</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgK_0tBtcTi0_C9gw4Gk3Lo1Kim44oBbqB8qQGV-9IeNo9Ar7Es-RlSVj3Kkr3znvVEiQiqQOeshdRCU6YyUvJLDjGNsKscXm0_1_l18AhNew-dtPEeRiH8yALnSxntvVEhB4b0bOlAmgaXoAg3Xj9ysaGhSv8l9DFV7fTxIiuaiYbJE8-gnHrg",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJ33SUNomAhYARUumvLnCj1yo",
#             "plus_code": {
#                 "compound_code": "QHQV+G9 Union Square, San Francisco, CA",
#                 "global_code": "849VQHQV+G9"
#             },
#             "rating": 3.5,
#             "reference": "ChIJ33SUNomAhYARUumvLnCj1yo",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 133,
#             "vicinity": "85 Campton Pl, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.3296076,
#                     "lng": -121.8859653
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.33100452989272,
#                         "lng": -121.8845154701072
#                     },
#                     "southwest": {
#                         "lat": 37.32830487010727,
#                         "lng": -121.8872151298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "f2e29a0b4e42594a6f7eba923c591fbad7cb3089",
#             "name": "Miami Beach Club",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102099299582494644151/photos\">Sharon Pope</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAB0pKbuw7TqMS2uTjSlepSIYuL34cmbIdlT97vk4YPp9a0jQoHH8CjU6vpl2OaPAIPIwICh7nyzIRc-Orow2UnLHmaVt_EkxKkCWyZcpWkxtusobe9jYW2m0CiJV_FbFpEhByw0HFRfNsj23aNnryzx9SGhT3eYPzIXO_w6Wwu7pVosM3piyOZQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJG-4cwLDMj4AR0S7eEZyTUlk",
#             "plus_code": {
#                 "compound_code": "84H7+RJ San Jose, California",
#                 "global_code": "849W84H7+RJ"
#             },
#             "rating": 4,
#             "reference": "ChIJG-4cwLDMj4AR0S7eEZyTUlk",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 82,
#             "vicinity": "417 S 1st St, San Jose"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.77731199999999,
#                     "lng": -122.403745
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77862752989272,
#                         "lng": -122.4025256201073
#                     },
#                     "southwest": {
#                         "lat": 37.77592787010727,
#                         "lng": -122.4052252798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "80c94a595326ede60dbe7eb2d083f11b38fb5709",
#             "name": "The EndUp",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1153,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108051781004381876913/photos\">The EndUp</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaIXDrwdRSVyQlt6GfLk3ovrtuIObWiZ9_uBCNrECVS8FBRK0k76i6k77Es3JlawFJduwW4N5mXJ_nJN8e254VJNk2lFVV9bQb1jInqDYeuWpEn3pUnl08smqSg-KTtQXEhBlCA3CcGujMUhdQ4EJajbyGhTPBfQ6geBs-hosiOcdHULuIgh6dw",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJOwXkLoCAhYAR4wOAUKL9gUI",
#             "plus_code": {
#                 "compound_code": "QHGW+WG SoMa, San Francisco, CA",
#                 "global_code": "849VQHGW+WG"
#             },
#             "price_level": 2,
#             "rating": 3.4,
#             "reference": "ChIJOwXkLoCAhYAR4wOAUKL9gUI",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 190,
#             "vicinity": "401 6th St, San Francisco"
#         }
#     ],
#     "status": "OK"
# }

# %%
print(len(sf_clubs["results"]))
# Out:
# 20

# %%
name=[]
vicinity =[]
lat = []
lng =[]
i= 0
while i < 20:
        name.append(sf_clubs["results"][i]["name"])
        vicinity.append((sf_clubs["results"][i]["vicinity"]))
        lat.append(sf_clubs["results"][i]['geometry']['location']['lat'])
        lng.append(sf_clubs["results"][i]['geometry']['location']['lng'])
        i+=1

clubs_dict = {
    "Club Name": name
    , "Address": vicinity
    , "Latitude": lat
    , "Longitude": lng
}
clubs_data = pd.DataFrame(clubs_dict)
clubs_data
# Out:
#                 Club Name                                     Address  \
# 0          Pure Nightclub                 146 S Murphy Ave, Sunnyvale
# 1                     HUE                 447 Broadway, San Francisco
# 2                  Origin             1538 Fillmore St, San Francisco
# 3                      F8               1192 Folsom St, San Francisco
# 4               The Grand                   520 4th St, San Francisco
# 5            The Holy Cow               1535 Folsom St, San Francisco
# 6      George's Nightclub                      842 4th St, San Rafael
# 7         Audio Nightclub                  316 11th St, San Francisco
# 8             1015 Folsom               1015 Folsom St, San Francisco
# 9                  Harlot                  46 Minna St, San Francisco
# 10            19 Broadway                        19 Broadway, Fairfax
# 11       ShBoom Nightclub  2410 San Ramon Valley Blvd #130, San Ramon
# 12                  OASIS                  298 11th St, San Francisco
# 13  The Uptown Nightclub!                 1928 Telegraph Ave, Oakland
# 14       Rouge Night Club                1500 Broadway, San Francisco
# 15            City Nights              715 Harrison St, San Francisco
# 16   ENSO Bar & Nightclub               97 E Santa Clara St, San Jose
# 17      Love + Propaganda                85 Campton Pl, San Francisco
# 18       Miami Beach Club                      417 S 1st St, San Jose
# 19              The EndUp                   401 6th St, San Francisco
#
#      Latitude   Longitude
# 0   37.376804 -122.029804
# 1   37.797948 -122.404785
# 2   37.783884 -122.432553
# 3   37.775291 -122.409961
# 4   37.779100 -122.397900
# 5   37.771375 -122.414310
# 6   37.972878 -122.524798
# 7   37.771362 -122.413792
# 8   37.778127 -122.405787
# 9   37.788569 -122.398197
# 10  37.986862 -122.587956
# 11  37.775480 -121.976335
# 12  37.771972 -122.414451
# 13  37.808588 -122.269635
# 14  37.796112 -122.421932
# 15  37.782060 -122.397636
# 16  37.337288 -121.888754
# 17  37.788790 -122.406598
# 18  37.329608 -121.885965
# 19  37.777312 -122.403745

# %%
crime=pd.read_csv("sf_crime.csv")

# %%
for col in crime.columns:
    print(col)
# Out:
# Incident Datetime
# Incident Date
# Incident Time
# Incident Year
# Incident Day of Week
# Report Datetime
# Row ID
# Incident ID
# Incident Number
# CAD Number
# Report Type Code
# Report Type Description
# Filed Online
# Incident Code
# Incident Category
# Incident Subcategory
# Incident Description
# Resolution
# Intersection
# CNN
# Police District
# Analysis Neighborhood
# Supervisor District
# Latitude
# Longitude
# point
# SF Find Neighborhoods
# Current Police Districts
# Current Supervisor Districts
# Analysis Neighborhoods
# HSOC Zones as of 2018-06-05
# OWED Public Spaces
# Central Market/Tenderloin Boundary Polygon - Updated
# Parks Alliance CPSI (27+TL sites)

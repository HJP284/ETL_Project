# %%
# Getting a list of Nightclubs in San Francisco
# We want to demostrate the use of APIs

# Dependencies
import requests
import json
import os
import gmaps
from pandas.io.json import json_normalize
import numpy as np
import pandas as pd
import requests
import time

# Google  API key
from config import gkey

gmaps.configure(api_key=gkey)

# %%
# Getting a list of Nightclubs in San Francisco
# We want to demostrate the use of APIs

# %%
target_coordinates = "37.7749,-122.4194"
target_search = "Nightclub"
target_radius = 50000
target_type = "nightclub"

# Setting up parameters
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
sf_clubs = response.json()

# Print the json (pretty printed)
print(json.dumps(sf_clubs, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCKwEAAPD37S3BtrX5ZxzvzAqwAavGJ8K47DDHgPJBjuevEIgviHoieU6-9v6sFBkITgz9h2b3WYG7pmA4imTCLopvJwUO14BZfndYeoUbuF8L7ilOWAjCt78VmSMdt9qXsRee7ukSC0PlAwZA5eOjEMqDbGQanluv0UbgY7_tEWBNink1-yRcovlM5bvDhyydRHS3G1CW7smI_p6Zr8sPdRYTUQUoK8F5-8zv6exYH2aVL65GTob2ApYKun2laHOTn6a7u_M_IwJEfKWWzth8uCE8yWqrx89yzvSpe1CZD0iUo2eyGx5XfBpBPat_8yr1az7kdb7fkjRlnfwPhvDzgR1G_HXr2C4-wLUHYaafYmyLvutmnTQEzyoYeO6TUKN8ZPzPIvO6riN_1rbj2rPGXmrciO4SEE5zJSK58QJEGodGRduj1vUaFKm6_VWkBPWHgQAMdKnwWfe6Nanj",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.3768037,
#                     "lng": -122.0298038
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.37818862989272,
#                         "lng": -122.0286148701073
#                     },
#                     "southwest": {
#                         "lat": 37.37548897010728,
#                         "lng": -122.0313145298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "1501bbd4f27bc5192be2721519813f6b11660d69",
#             "name": "Pure Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116548265877372563340/photos\">Steven Leung</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgIjltDd1DUyU4EfYCAEYx_3P8534D49b5RZGZbZ0qix7Yiq90f068mAXEEgMa7zgni0crXPX4W5bLCxiu9RhmPx5HyZVzuCMtZ68jj5cIOvF8T1EX4EZH_5TnxoULRm1EhCthdZCZg2fz0PCmgtIUo8mGhRG2UrnobrDMst8m67wX2C53XKD_A",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ5RwEVly2j4ARAAp9ATndYxc",
#             "plus_code": {
#                 "compound_code": "9XGC+P3 Sunnyvale, California",
#                 "global_code": "849V9XGC+P3"
#             },
#             "price_level": 2,
#             "rating": 3.5,
#             "reference": "ChIJ5RwEVly2j4ARAAp9ATndYxc",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 152,
#             "vicinity": "146 S Murphy Ave, Sunnyvale"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.797948,
#                     "lng": -122.4047847
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.79938112989272,
#                         "lng": -122.4034520201073
#                     },
#                     "southwest": {
#                         "lat": 37.79668147010728,
#                         "lng": -122.4061516798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "f7b4baafbb37bf537134c1743bc77e4750702325",
#             "name": "HUE",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100319726892602982658/photos\">Gleizy Fonseca</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAj2mwLYSvydpzDDfGJNckjU0185fEGno5tLIS4743hxpOJ69YWQxdq4bPKuE3mmbbgfEwbg72DUCWlAkinOkaV977FCpg0NHVZ_JhkZ_7azMXsknIJyRkqJr1a8CS75hXEhDpvl6ZNCGVMDw-aLEUAwlGGhR2O07RBHxddOYKmZQkvTH3-Bx22g",
#                     "width": 1944
#                 }
#             ],
#             "place_id": "ChIJFXzz-PSAhYARdawj6Vezo9g",
#             "plus_code": {
#                 "compound_code": "QHXW+53 Financial District, San Francisco, CA",
#                 "global_code": "849VQHXW+53"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJFXzz-PSAhYARdawj6Vezo9g",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "447 Broadway, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7838841,
#                     "lng": -122.4325529
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78524017989272,
#                         "lng": -122.4313492201073
#                     },
#                     "southwest": {
#                         "lat": 37.78254052010728,
#                         "lng": -122.4340488798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "35ff479da7dfc5ce3ff136b26a82f693a4a9569a",
#             "name": "Origin",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109441328719820863810/photos\">Marie Luise Cajayon</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAKYuTkwKCq84GSQ5ncFuhKUbYAME42Nq01nobk5FHXNVVwztptZw0NMh-ynEkeIndNkYvGt9ATzifd9pdP1VnMwOxBXxQh1gdyfWo7tsoKs8-gl2iCnCrJxbPfyK31aT0EhBEtmjHdi0hk5-muDfSkfasGhQzXNCgnVEv28vh6BmX_QZM5KzM1Q",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJMx0ap7mAhYARaJPoM6Pc6eg",
#             "plus_code": {
#                 "compound_code": "QHM8+HX Western Addition, San Francisco, CA",
#                 "global_code": "849VQHM8+HX"
#             },
#             "price_level": 2,
#             "rating": 3.3,
#             "reference": "ChIJMx0ap7mAhYARaJPoM6Pc6eg",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 48,
#             "vicinity": "1538 Fillmore St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.775291,
#                     "lng": -122.4099614
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77659607989272,
#                         "lng": -122.4085484701073
#                     },
#                     "southwest": {
#                         "lat": 37.77389642010728,
#                         "lng": -122.4112481298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "3e0a894f8704a08e0b968127c47a2c82750664a2",
#             "name": "F8",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111373865606276521052/photos\">Charley Ho</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5WsLOAa4KY5CFT87axCc0A8_GyzRx88deWp7GKZ7tPfobnA0RRGITq0l7b5tpQ53QL41bHEFMuhgXURIxgepQ367IY9HQ--R6T0TYreRLE7NUnQnnEjg7FvLQZhhj_LgEhD2gE4IA442-SbW25r-W55gGhSnDzxQyaRY7MZVc3wPxW1T7iJFpQ",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJm5TigIKAhYARZ_AATy2Ieu4",
#             "plus_code": {
#                 "compound_code": "QHGR+42 SoMa, San Francisco, CA",
#                 "global_code": "849VQHGR+42"
#             },
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "ChIJm5TigIKAhYARZ_AATy2Ieu4",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 147,
#             "vicinity": "1192 Folsom St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7790996,
#                     "lng": -122.3979003
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78050357989272,
#                         "lng": -122.3964783201073
#                     },
#                     "southwest": {
#                         "lat": 37.77780392010728,
#                         "lng": -122.3991779798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "18e74c4aa201e64722d8414f3166d180244d8aa9",
#             "name": "The Grand",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4903,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102119050734171212729/photos\">Liz Cantu Davenport</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPemGYpl7Kt8-V5n2SpdNpauqV6OjDlxwMjiqF5pgf8L4dj1PdHwKY1WAc74skHIckxL6FcsJwcdLXQoEe0AqggWmCXvJSFAbvH2pbfVH1XVVnLPjaDqYJxMSbiTK66sLEhDe9Ue_oBUYa7op73PKYcUXGhT2pu8P7jNUKZNlN4S9ZkstH1uR5g",
#                     "width": 7347
#                 }
#             ],
#             "place_id": "ChIJO6fCZH-AhYARbmHHgxnFxB8",
#             "plus_code": {
#                 "compound_code": "QJH2+JR SoMa, San Francisco, CA",
#                 "global_code": "849VQJH2+JR"
#             },
#             "price_level": 3,
#             "rating": 3.5,
#             "reference": "ChIJO6fCZH-AhYARbmHHgxnFxB8",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 112,
#             "vicinity": "520 4th St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7713746,
#                     "lng": -122.4143099
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77279862989273,
#                         "lng": -122.4130640701073
#                     },
#                     "southwest": {
#                         "lat": 37.77009897010728,
#                         "lng": -122.4157637298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "52f749412fccb5f7372d8a461cc80fc455e3f8cb",
#             "name": "The Holy Cow",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103348007688594899143/photos\">Preksha Shukla</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxVnTaX6FZ0D5zLh9YhkOr-FLkK0ToQZame-X1Jk426I-nJXwJAiUlMO4fAyX5JUD1dV7mQazWc4f6ApWnEQHtqNDcCv1B5_FD-wYHoizEuxStww_BleiYTR-mB_8N20_EhAWPQD-OKZs77_2GVa7h5l5GhS1y6fe7KajsQUAz62HAyewgRGBQg",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJMTRftCd-j4ARWTvQZOTDNM0",
#             "plus_code": {
#                 "compound_code": "QHCP+G7 SoMa, San Francisco, CA",
#                 "global_code": "849VQHCP+G7"
#             },
#             "price_level": 2,
#             "rating": 3.1,
#             "reference": "ChIJMTRftCd-j4ARWTvQZOTDNM0",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 60,
#             "vicinity": "1535 Folsom St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.9728783,
#                     "lng": -122.5247984
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.97417192989272,
#                         "lng": -122.5234594201073
#                     },
#                     "southwest": {
#                         "lat": 37.97147227010728,
#                         "lng": -122.5261590798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "97c7e73f498887a2e8fa0459a49e913e33e5d51b",
#             "name": "George's Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111810312065171874458/photos\">Josue Gabriel Chicas</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA41JMQSArqXEUmTPdMjYNvkDewRzspKE3UcYTdWYTVDoo65bhU8rULf2dK8lMjFr1nX2oIOxZ9JRppfRJhOZgGD0mXw18iVhf5TfCT2mMugcoL0n3V2Kc0VF2ELfrC4P4EhCwI2vG-qrrvqPzRGqbwdF3GhT0gYZsJ17AU1Ns6M_DTr_Vy2ukhw",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJAWd8tPCZhYARQtzK8sBGjW0",
#             "plus_code": {
#                 "compound_code": "XFFG+53 San Rafael, California",
#                 "global_code": "849VXFFG+53"
#             },
#             "rating": 3.3,
#             "reference": "ChIJAWd8tPCZhYARQtzK8sBGjW0",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "842 4th St, San Rafael"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.771362,
#                     "lng": -122.413792
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77278862989272,
#                         "lng": -122.4123443701072
#                     },
#                     "southwest": {
#                         "lat": 37.77008897010727,
#                         "lng": -122.4150440298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "e1edec5cd007c1172a4af29b0ac8fa96298e7185",
#             "name": "Audio Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1440,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100366883861598066793/photos\">Frank Ebert</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAktWw2H02IyR9VkVD7fAktYqKwMmUT7eiaKm_js_TvVakeDZVluWuCAa-mMGaYEjg0k7UzIa4PNNDGB1zRs6JdLs96aTv7RqjkHOWSo-SqLRvnHpxj9twnCh5kYZZGv__EhDmnZ1p6aqzpZ5eIek9nkHSGhQPA67hm3_2o2PVO02Q7fbRi1tZtg",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJ-45DMyZ-j4AR2Apt3H8M8W8",
#             "plus_code": {
#                 "compound_code": "QHCP+GF SoMa, San Francisco, CA",
#                 "global_code": "849VQHCP+GF"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJ-45DMyZ-j4AR2Apt3H8M8W8",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 166,
#             "vicinity": "316 11th St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7781268,
#                     "lng": -122.405787
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77955922989271,
#                         "lng": -122.4045067201073
#                     },
#                     "southwest": {
#                         "lat": 37.77685957010727,
#                         "lng": -122.4072063798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "e30254400171df555b96784f93c4168a4cdb511a",
#             "name": "1015 Folsom",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110735291300890193560/photos\">rWilliam Brown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAZjZqmvAcq5ee7sy_eBaWUs8tZrLFUv5r1xRrFt3khP3bEWyGYjlhuFamMqwiEYlL3TuoMX44ZgBfWnAIziwr0v-dkYGrFWbgBGG2CtRyE_F8uRorGQTryvGv2wRdXbL5EhAJwliLZc-UY6br3qEGrhcjGhRGXLD-cYjeVkN3GveDoEObNauNjw",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJRwXhl4GAhYARKMdYXvUW1m8",
#             "plus_code": {
#                 "compound_code": "QHHV+7M SoMa, San Francisco, CA",
#                 "global_code": "849VQHHV+7M"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJRwXhl4GAhYARKMdYXvUW1m8",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 251,
#             "vicinity": "1015 Folsom St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.771972,
#                     "lng": -122.4144509
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77336507989272,
#                         "lng": -122.4130118701073
#                     },
#                     "southwest": {
#                         "lat": 37.77066542010727,
#                         "lng": -122.4157115298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "a6e86de55360cfbe76a9b651f0d2d2b3bf867280",
#             "name": "OASIS",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116420115838609488002/photos\">Oasis</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApLMlJhwY7dzsCXt3sAXVKcg-1BhttgJtKveENqIYIYhEi8_NsmBZyRS4gkrChjPn05o6SqmHwDjwMm7xAmOnEQBe1ey2un8XxZQT3-hgNQLkRwGXVr_g4yvg2hpM7xSQEhAC9fNK2kWKkhbnTWlv6gAiGhTXJa6KTYlXD8DrzBahtCPZZDJtMw",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJt3rauSd-j4ARlPtSevL_VQY",
#             "plus_code": {
#                 "compound_code": "QHCP+Q6 SoMa, San Francisco, CA",
#                 "global_code": "849VQHCP+Q6"
#             },
#             "rating": 4.3,
#             "reference": "ChIJt3rauSd-j4ARlPtSevL_VQY",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 74,
#             "vicinity": "298 11th St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7885694,
#                     "lng": -122.3981969
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78988832989272,
#                         "lng": -122.3968000701073
#                     },
#                     "southwest": {
#                         "lat": 37.78718867010727,
#                         "lng": -122.3994997298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "d666f7f1fa3af01c56f0265c7cee49d67e3298e9",
#             "name": "Harlot",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101194371142924116371/photos\">Houdini</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAECRCpXOxASxN_W55ivJUSJdvnPvuHr_AHP0y_vX9M0damxDPhOfXsPbgF8DwdjobTmXV8V4kVXnmMohP8-Bde7Yyb1NJ__gAHF4vKGYjvzCV0dXlRiNUAacoo_a68jyEhCCZwucUZ9ilPAku_oUImD5GhRMxGT4ZhnbHalZlOisyttSpzjbzQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ_wvnLmOAhYARfjey1qtQmg4",
#             "plus_code": {
#                 "compound_code": "QJQ2+CP SoMa, San Francisco, CA",
#                 "global_code": "849VQJQ2+CP"
#             },
#             "price_level": 3,
#             "rating": 3.7,
#             "reference": "ChIJ_wvnLmOAhYARfjey1qtQmg4",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 94,
#             "vicinity": "46 Minna St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.9868616,
#                     "lng": -122.5879555
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.98820787989273,
#                         "lng": -122.5865386701073
#                     },
#                     "southwest": {
#                         "lat": 37.98550822010728,
#                         "lng": -122.5892383298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "90469932a147bede21fc205590233bdf4955175e",
#             "name": "19 Broadway",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111166131312787211650/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA_FhSEYwrPTX3fDLJ3HPXQh39CDgw15GA4u0QuwVIiFvA-HiT0jXEU0TBgBH_Mov4D-7HZWX3WQfISOYYzjK-v8vDBQOR4MJunRpDU15jyOb7gJPkJZwznwJwJy4_h1ZPEhBMXLaMT1MQs8qEgHOSw0bNGhSOf0Sdwgp-_hAl7zcAfuFiNMUKHQ",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ44vR_FWWhYARNIvh6gYMTUY",
#             "plus_code": {
#                 "compound_code": "XCP6+PR Fairfax, California",
#                 "global_code": "849VXCP6+PR"
#             },
#             "price_level": 2,
#             "rating": 4.5,
#             "reference": "ChIJ44vR_FWWhYARNIvh6gYMTUY",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "19 Broadway, Fairfax"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.77548,
#                     "lng": -121.976335
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77667642989272,
#                         "lng": -121.9750554701073
#                     },
#                     "southwest": {
#                         "lat": 37.77397677010728,
#                         "lng": -121.9777551298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "d3be690b01527cbab112ba0a722f562913d7c2ea",
#             "name": "ShBoom Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 513,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115091909746257986308/photos\">ShBoom Nightclub</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAoNqMsVQiUlhVJDQpgN1sGN154KQKKCt-awDF_iNivMScT7UQ6_D1eAEpSCai-Rtcf7ZyOKBU7akDZa-65o1wqxM5ltGglKp7PaFbRfq7hsibakDJ9lAhK7tXwcULVGJZEhDFblmEK82mhpcaR_DnB5K-GhSRTmixf-8JKBnAa4nfw1VCtlSbEA",
#                     "width": 793
#                 }
#             ],
#             "place_id": "ChIJR-2WNsfyj4AR7uefmq-1xI0",
#             "plus_code": {
#                 "compound_code": "Q2GF+5F San Ramon, California",
#                 "global_code": "849WQ2GF+5F"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJR-2WNsfyj4AR7uefmq-1xI0",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 86,
#             "vicinity": "2410 San Ramon Valley Blvd #130, San Ramon"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7820604,
#                     "lng": -122.3976355
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.78345047989273,
#                         "lng": -122.3964383701073
#                     },
#                     "southwest": {
#                         "lat": 37.78075082010728,
#                         "lng": -122.3991380298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "8467a5e7b16a2cb3c958b5d784b7a7a72657b540",
#             "name": "City Nights",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111881477538410001809/photos\">Matthew Zolezzi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA7QOS4HvJBykps0iSOapSd27MCM6PyvaXqdNYH5tQikvGwtjRAfCk2Z9SjOZH_j076IIFetIYXBMCRPPfbNlFJNfYPOOb11QuRYyayNmlq2ohvOx290_Xot4f3Elr9lziEhCY5uncPCzx1HlskQT4W9LxGhRTwLHnQgO_viabF3Cc1bWlzvGjoA",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJeZ2e7n6AhYARVjvP9N8mEcs",
#             "plus_code": {
#                 "compound_code": "QJJ2+RW SoMa, San Francisco, CA",
#                 "global_code": "849VQJJ2+RW"
#             },
#             "price_level": 2,
#             "rating": 3.8,
#             "reference": "ChIJeZ2e7n6AhYARVjvP9N8mEcs",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 110,
#             "vicinity": "715 Harrison St, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.8085876,
#                     "lng": -122.269635
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.80995777989272,
#                         "lng": -122.2683785201072
#                     },
#                     "southwest": {
#                         "lat": 37.80725812010727,
#                         "lng": -122.2710781798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "5dc37f315cc16fb4912ebd5def8449fdbbe03935",
#             "name": "The Uptown Nightclub!",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 750,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111649149702197963031/photos\">Uptown Night Club</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgoOGS2aEYG64SpmZbAm6lQGPOdn4oGprZvW14pv0aeGNV3cBkead1d8zwz1DUjsbZahnDZPhs6RJYo1FYwNZKJYtAbmmUHyXNm25fAB0ZawWg5r7WTlW7X8XYFiCZBnREhAM15-O6D5DXumwwmHuDXTSGhQv0dWNsdOg4mbz9YTarkoErcjitw",
#                     "width": 1800
#                 }
#             ],
#             "place_id": "ChIJW1nriq2Aj4ARfDmscjzBQyk",
#             "plus_code": {
#                 "compound_code": "RP5J+C4 Oakland, California",
#                 "global_code": "849VRP5J+C4"
#             },
#             "rating": 4.2,
#             "reference": "ChIJW1nriq2Aj4ARfDmscjzBQyk",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "1928 Telegraph Ave, Oakland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7961123,
#                     "lng": -122.421932
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.79739042989273,
#                         "lng": -122.4205290201073
#                     },
#                     "southwest": {
#                         "lat": 37.79469077010728,
#                         "lng": -122.4232286798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "f3f5ba9170340f1be6667e4367ca00b6fcb72c44",
#             "name": "Rouge Night Club",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108615940274457531719/photos\">Rouge Night Club</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAItRT3FEfnf6P3D0eD_mQbF1p0Ac0RE_eKiT9DEspqYXt0uGt9f-uJhN96Wgv5CVHcM7JjZgHGmA4J3Tea1GSGEFXrf1Dwmj1pjPrcU57xV8v-ZLefJ4xOZLab8qlWX-nEhDS4gSJqtXdkowj1fxDS7hAGhS9mddSBl2pwlRMrcHqRosNTaWy5w",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJe3uYkOmAhYAR8gdCXjJNyeQ",
#             "plus_code": {
#                 "compound_code": "QHWH+C6 Russian Hill, San Francisco, CA",
#                 "global_code": "849VQHWH+C6"
#             },
#             "price_level": 2,
#             "rating": 3.4,
#             "reference": "ChIJe3uYkOmAhYAR8gdCXjJNyeQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "1500 Broadway, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.7887903,
#                     "lng": -122.4065981
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.79025292989272,
#                         "lng": -122.4052492201073
#                     },
#                     "southwest": {
#                         "lat": 37.78755327010727,
#                         "lng": -122.4079488798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "83528866af26da1035875c3ea3b6528490ddc95a",
#             "name": "Love + Propaganda",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 683,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102527170037305091749/photos\">Love and Propaganda</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAOUr6HYDmG65bXDxcPomQnQbue-3kTIQPAEDirIGIPzw2Ria2xEzbMiwXV1qoBgRXZrT0XyrpiUviBoOZ8IT0I7n3BmhByMLU9yopQGIQHSTDFpW3wzh0Y5VGParay78dEhBTchGouTQdawhYOZaYalQ9GhTk5q7EwQBhTwUD9D6Hq9B3xYk4gg",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJ33SUNomAhYARUumvLnCj1yo",
#             "plus_code": {
#                 "compound_code": "QHQV+G9 Union Square, San Francisco, CA",
#                 "global_code": "849VQHQV+G9"
#             },
#             "rating": 3.5,
#             "reference": "ChIJ33SUNomAhYARUumvLnCj1yo",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 133,
#             "vicinity": "85 Campton Pl, San Francisco"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.337288,
#                     "lng": -121.8887537
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.33855107989272,
#                         "lng": -121.8873378201072
#                     },
#                     "southwest": {
#                         "lat": 37.33585142010728,
#                         "lng": -121.8900374798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "133eb3a6943aa2deeef3be8a9a184ac0a84e2bf1",
#             "name": "ENSO Bar & Nightclub",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3056,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100154901588069212708/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFIjbOONyJRyI71cNQ4eCn2HtKB8Lz8xASmYspb01LYOaZpLfMIz5e98Vg0kbcmul2Q0mVotBCFH4RujuJfeVk9RJ6TaLcbp2lmUk3XoVvij14HFi35yv4p6Ji1-FhnRtEhATtunaIl54Pvis5ab2qEHyGhS84rCsZaYBhrrskUTZLzyUQ6-QgQ",
#                     "width": 4592
#                 }
#             ],
#             "place_id": "ChIJG5FGHr3Mj4ART-GSHQlVhHU",
#             "plus_code": {
#                 "compound_code": "84P6+WF San Jose, California",
#                 "global_code": "849W84P6+WF"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJG5FGHr3Mj4ART-GSHQlVhHU",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 172,
#             "vicinity": "97 E Santa Clara St, San Jose"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.3296076,
#                     "lng": -121.8859653
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.33100452989272,
#                         "lng": -121.8845154701072
#                     },
#                     "southwest": {
#                         "lat": 37.32830487010727,
#                         "lng": -121.8872151298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "f2e29a0b4e42594a6f7eba923c591fbad7cb3089",
#             "name": "Miami Beach Club",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102099299582494644151/photos\">Sharon Pope</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPAZrwjvaVtYbR6LIZOfU1nR8nfL149qsI7IEocUfGIZ8riEKpa96M8moO7qeDtz2-Lb5g8vlfZcBDs6j1O-d9iQqoanyctI-TrtdKly7u6d9zc4Uo7hEDqv0qc5PzHQgEhAnmvY884y0vKu4bBwolI1iGhSzuGxtgaFHmAjBaYgW1ZqmNuZr5A",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJG-4cwLDMj4AR0S7eEZyTUlk",
#             "plus_code": {
#                 "compound_code": "84H7+RJ San Jose, California",
#                 "global_code": "849W84H7+RJ"
#             },
#             "rating": 4,
#             "reference": "ChIJG-4cwLDMj4AR0S7eEZyTUlk",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 82,
#             "vicinity": "417 S 1st St, San Jose"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 37.77731199999999,
#                     "lng": -122.403745
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.77862752989272,
#                         "lng": -122.4025256201073
#                     },
#                     "southwest": {
#                         "lat": 37.77592787010727,
#                         "lng": -122.4052252798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "80c94a595326ede60dbe7eb2d083f11b38fb5709",
#             "name": "The EndUp",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1153,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108051781004381876913/photos\">The EndUp</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAflec9X-5KqMdYdJ1t_ajM4l8JOqMWDP9kBKRAZUfeujPkRqQGA0ttS9S54M-OZKy-2ZOaNd2LeffbSPWorpn9hINS4kYNOIj0rLkamCLr1ya8TSUF0Eq-y7SDEMZCdNEEhATg6tQ08tInc1-FCFU2AEWGhTPGlXXIbFB5_Ri0IdkrMIMgDloew",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJOwXkLoCAhYAR4wOAUKL9gUI",
#             "plus_code": {
#                 "compound_code": "QHGW+WG SoMa, San Francisco, CA",
#                 "global_code": "849VQHGW+WG"
#             },
#             "price_level": 2,
#             "rating": 3.4,
#             "reference": "ChIJOwXkLoCAhYAR4wOAUKL9gUI",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 190,
#             "vicinity": "401 6th St, San Francisco"
#         }
#     ],
#     "status": "OK"
# }

# %%
print(len(sf_clubs["results"]))
# Out:
# 20

# %%
print(sf_clubs["results"][0]["name"])
# Out:
# Pure Nightclub

# %%
crime=pd.read_csv("sf_2018.csv")

# %%
crime.head(5)

# %%
for col in crime.columns:
    print(col)
